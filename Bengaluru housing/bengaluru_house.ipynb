# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Bengaluru_House_Data.csv')
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df['total_sqft'].value_counts()
df['total_sqft'].unique()
sqft=[]
for d in df['total_sqft']:
    if '-' in d:
        k=d.split(' - ')
        sqft.append(float(k[0])+float(k[1])/2)
    elif d.isnumeric():
        sqft.append(d)
        
        
    else:
        sqft.append(None)
df['total_sqft']=sqft
df['total_sqft']
# Out:
# 0        1056
# 1        2600
# 2        1440
# 3        1521
# 4        1200
#          ...
# 13315    3453
# 13316    3600
# 13317    1141
# 13318    4689
# 13319     550
# Name: total_sqft, Length: 13320, dtype: object

# %%
for m in df['total_sqft']:
    print(m)
# Out:
# 1056
# 2600
# 1440
# 1521
# 1200
# 1170
# 2732
# 3300
# 1310
# 1020
# 1800
# 2785
# 1000
# 1100
# 2250
# 1175
# 1180
# 1540
# 2770
# 1100
# 600
# 1755
# 2800
# 1767
# 510
# 1250
# 660
# 1610
# 1151
# 1025
# 3525.0
# 1075
# 1760
# 1693
# 1925
# 700
# 1070
# 1724
# 1290
# 1143
# 1296
# 1254
# 600
# 660
# None
# 600
# 970
# 1459
# 800
# 869
# 1270
# 1670
# 2010
# 1185
# 1600
# 1200
# 4715.0
# 1500
# 1407
# 840
# 4395
# 845
# 5700
# 1160
# 3000
# 1100
# 1140
# 1220
# 1350
# 1005
# 500
# 1358
# 1569
# 1240
# 2089
# 1206
# 1150
# 2511
# 460
# 4400
# 1660
# 4682.0
# 1326
# 1325
# 1499
# 3000
# 1665
# 708
# 1060
# 710
# 1000
# 1000
# 1450
# 1200
# 1296
# 1540
# 2894
# 1330
# 1200
# 1200
# 2502
# 650
# 2400
# 1007
# 1200
# 966
# 1630
# 1640
# 782
# 1260
# 1800
# 1413
# 1116
# 1530
# 3700
# 2497
# 1540
# 1436
# 1100
# 276
# 1427
# 2061
# 7145.0
# 2650
# 1282
# 1050
# 1600
# 945
# 1500
# 950
# 1870
# 1600
# 880
# 1200
# 1535
# 950
# 1360
# 1594.5
# 1280
# 1260
# 5000
# 3050
# None
# 1000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13187 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft       133
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df['total_sqft']=df['total_sqft'].fillna(method='bfill')
# Out:
# /var/folders/vk/24j_xhv17pzdvd9jmf97hcc80000gn/T/ipykernel_85957/1046758178.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['total_sqft']=df['total_sqft'].fillna(method='bfill')

# %%
df['total_sqft']=df['total_sqft'].astype(int)

# %%
for m in df['total_sqft']:
    print(m)
# Out:
# 1056
# 2600
# 1440
# 1521
# 1200
# 1170
# 2732
# 3300
# 1310
# 1020
# 1800
# 2785
# 1000
# 1100
# 2250
# 1175
# 1180
# 1540
# 2770
# 1100
# 600
# 1755
# 2800
# 1767
# 510
# 1250
# 660
# 1610
# 1151
# 1025
# 3525
# 1075
# 1760
# 1693
# 1925
# 700
# 1070
# 1724
# 1290
# 1143
# 1296
# 1254
# 600
# 660
# 600
# 600
# 970
# 1459
# 800
# 869
# 1270
# 1670
# 2010
# 1185
# 1600
# 1200
# 4715
# 1500
# 1407
# 840
# 4395
# 845
# 5700
# 1160
# 3000
# 1100
# 1140
# 1220
# 1350
# 1005
# 500
# 1358
# 1569
# 1240
# 2089
# 1206
# 1150
# 2511
# 460
# 4400
# 1660
# 4682
# 1326
# 1325
# 1499
# 3000
# 1665
# 708
# 1060
# 710
# 1000
# 1000
# 1450
# 1200
# 1296
# 1540
# 2894
# 1330
# 1200
# 1200
# 2502
# 650
# 2400
# 1007
# 1200
# 966
# 1630
# 1640
# 782
# 1260
# 1800
# 1413
# 1116
# 1530
# 3700
# 2497
# 1540
# 1436
# 1100
# 276
# 1427
# 2061
# 7145
# 2650
# 1282
# 1050
# 1600
# 945
# 1500
# 950
# 1870
# 1600
# 880
# 1200
# 1535
# 950
# 1360
# 1594
# 1280
# 1260
# 5000
# 3050
# 1000
# 1000
# 1167
# 4000
# ...

# %%
df.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size             object
# society          object
# total_sqft        int64
# bath            float64
# balcony         float64
# price           float64
# dtype: object

# %%
df['location']=df['location'].fillna(method='bfill')
# Out:
# /var/folders/vk/24j_xhv17pzdvd9jmf97hcc80000gn/T/ipykernel_85957/4171001926.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['location']=df['location'].fillna(method='bfill')

# %%
df['location'].isnull().sum()
# Out:
# 0

# %%
df['bath']=df['bath'].fillna(method='bfill')
# Out:
# /var/folders/vk/24j_xhv17pzdvd9jmf97hcc80000gn/T/ipykernel_85957/1494869844.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['bath']=df['bath'].fillna(method='bfill')

# %%
df['bath'].isnull().sum()
# Out:
# 0

# %%
df['balcony']=df['balcony'].fillna(method='bfill')
# Out:
# /var/folders/vk/24j_xhv17pzdvd9jmf97hcc80000gn/T/ipykernel_85957/94580203.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['balcony']=df['balcony'].fillna(method='bfill')

# %%
df['balcony'].unique()
# Out:
# array([1., 3., 2., 0.])

# %%
df['balcony'].isnull().sum()
# Out:
# 0

# %%
df['size']=df['size'].fillna(method='ffill')
# Out:
# /var/folders/vk/24j_xhv17pzdvd9jmf97hcc80000gn/T/ipykernel_85957/1058710012.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['size']=df['size'].fillna(method='ffill')

# %%
df['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
Bedroom=[]
for i in df['size']:
    i=i.split()
    Bedroom.append(i[0])
Bedroom
df['Bedroom']=Bedroom

# %%
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society  total_sqft  bath  balcony   price Bedroom
# 0  Coomee         1056   2.0      1.0   39.07       2
# 1  Theanmp        2600   5.0      3.0  120.00       4
# 2      NaN        1440   2.0      3.0   62.00       3
# 3  Soiewre        1521   3.0      1.0   95.00       3
# 4      NaN        1200   2.0      1.0   51.00       2

# %%
39*100000
# Out:
# 3900000

# %%
df.drop('size',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13320 non-null  object
#  3   society       7818 non-null   object
#  4   total_sqft    13320 non-null  int64
#  5   bath          13320 non-null  float64
#  6   balcony       13320 non-null  float64
#  7   price         13320 non-null  float64
#  8   Bedroom       13320 non-null  object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 936.7+ KB

# %%
df['balcony'].mean()
# Out:
# 1.5833333333333333

# %%
df.drop('society',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# Bedroom         0
# dtype: int64

# %%
df['bath']=df['bath'].astype(int)
df['balcony']=df['balcony'].astype(int)
df['Bedroom']=df['Bedroom'].astype(int)

# %%
df.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# total_sqft        int64
# bath              int64
# balcony           int64
# price           float64
# Bedroom           int64
# dtype: object

# %%
df.head()
# Out:
#               area_type   availability                  location  total_sqft  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II        1056
# 1            Plot  Area  Ready To Move          Chikka Tirupathi        2600
# 2        Built-up  Area  Ready To Move               Uttarahalli        1440
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli        1521
# 4  Super built-up  Area  Ready To Move                  Kothanur        1200
#
#    bath  balcony   price  Bedroom
# 0     2        1   39.07        2
# 1     5        3  120.00        4
# 2     2        3   62.00        3
# 3     3        1   95.00        3
# 4     2        1   51.00        2

# %%
df['availability'].unique()
# Out:
# array(['19-Dec', 'Ready To Move', '18-May', '18-Feb', '18-Nov', '20-Dec',
#        '17-Oct', '21-Dec', '19-Sep', '20-Sep', '18-Mar', '20-Feb',
#        '18-Apr', '20-Aug', '18-Oct', '19-Mar', '17-Sep', '18-Dec',
#        '17-Aug', '19-Apr', '18-Jun', '22-Dec', '22-Jan', '18-Aug',
#        '19-Jan', '17-Jul', '18-Jul', '21-Jun', '20-May', '19-Aug',
#        '18-Sep', '17-May', '17-Jun', '21-May', '18-Jan', '20-Mar',
#        '17-Dec', '16-Mar', '19-Jun', '22-Jun', '19-Jul', '21-Feb',
#        'Immediate Possession', '19-May', '17-Nov', '20-Oct', '20-Jun',
#        '19-Feb', '21-Oct', '21-Jan', '17-Mar', '17-Apr', '22-May',
#        '19-Oct', '21-Jul', '21-Nov', '21-Mar', '16-Dec', '22-Mar',
#        '20-Jan', '21-Sep', '21-Aug', '14-Nov', '19-Nov', '15-Nov',
#        '16-Jul', '15-Jun', '17-Feb', '20-Nov', '20-Jul', '16-Sep',
#        '15-Oct', '15-Dec', '16-Oct', '22-Nov', '15-Aug', '17-Jan',
#        '16-Nov', '20-Apr', '16-Jan', '14-Jul'], dtype=object)

# %%
df.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# total_sqft        int64
# bath              int64
# balcony           int64
# price           float64
# Bedroom           int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
df['area_type']=label.fit_transform(df['area_type'])
df['availability']=label.fit_transform(df['availability'])
df['location']=label.fit_transform(df['location'])

# %%
df.drop(index=[13315])
# Out:
#        area_type  availability  location  total_sqft  bath  balcony   price  \
# 0              3            40       419        1056     2        1   39.07
# 1              2            80       317        2600     5        3  120.00
# 2              0            80      1179        1440     2        3   62.00
# 3              3            80       757        1521     3        1   95.00
# 4              3            80       716        1200     2        1   51.00
# ...          ...           ...       ...         ...   ...      ...     ...
# 13314          3            80       474        1715     3        3  112.00
# 13316          3            80      1004        3600     5        1  400.00
# 13317          0            80       972        1141     2        1   60.00
# 13318          3            32       907        4689     4        1  488.00
# 13319          3            80       396         550     1        1   17.00
#
#        Bedroom
# 0            2
# 1            4
# ...

# %%
df=df.rename(columns={'bath':'Bathroom'})

# %%
df
# Out:
#        area_type  availability  location  total_sqft  Bathroom  balcony  \
# 0              3            40       419        1056         2        1
# 1              2            80       317        2600         5        3
# 2              0            80      1179        1440         2        3
# 3              3            80       757        1521         3        1
# 4              3            80       716        1200         2        1
# ...          ...           ...       ...         ...       ...      ...
# 13315          0            80      1252        3453         4        0
# 13316          3            80      1004        3600         5        1
# 13317          0            80       972        1141         2        1
# 13318          3            32       907        4689         4        1
# 13319          3            80       396         550         1        1
#
#         price  Bedroom
# 0       39.07        2
# 1      120.00        4
# 2       62.00        3
# ...

# %%
p=[]
for j in df['price']:
    p.append(j*100000)
df['price']=p

# %%
df['price']=df['price'].astype(int)

# %%
df['total_sqft'].dtypes
# Out:
# dtype('int64')

# %%
y=df['price']
x=df.drop('price',axis=1)

# %%
x
# Out:
#        area_type  availability  location  total_sqft  Bathroom  balcony  \
# 0              3            40       419        1056         2        1
# 1              2            80       317        2600         5        3
# 2              0            80      1179        1440         2        3
# 3              3            80       757        1521         3        1
# 4              3            80       716        1200         2        1
# ...          ...           ...       ...         ...       ...      ...
# 13315          0            80      1252        3453         4        0
# 13316          3            80      1004        3600         5        1
# 13317          0            80       972        1141         2        1
# 13318          3            32       907        4689         4        1
# 13319          3            80       396         550         1        1
#
#        Bedroom
# 0            2
# 1            4
# 2            3
# 3            3
# 4            2
# ...

# %%
y
# Out:
# 0         3907000
# 1        12000000
# 2         6200000
# 3         9500000
# 4         5100000
#            ...
# 13315    23100000
# 13316    40000000
# 13317     6000000
# 13318    48800000
# 13319     1700000
# Name: price, Length: 13320, dtype: int64

# %%
x
# Out:
#        area_type  availability  location  total_sqft  Bathroom  balcony  \
# 0              3            40       419        1056         2        1
# 1              2            80       317        2600         5        3
# 2              0            80      1179        1440         2        3
# 3              3            80       757        1521         3        1
# 4              3            80       716        1200         2        1
# ...          ...           ...       ...         ...       ...      ...
# 13315          0            80      1252        3453         4        0
# 13316          3            80      1004        3600         5        1
# 13317          0            80       972        1141         2        1
# 13318          3            32       907        4689         4        1
# 13319          3            80       396         550         1        1
#
#        Bedroom
# 0            2
# 1            4
# 2            3
# 3            3
# 4            2
# ...

# %%
df
# Out:
#        area_type  availability  location  total_sqft  Bathroom  balcony  \
# 0              3            40       419        1056         2        1
# 1              2            80       317        2600         5        3
# 2              0            80      1179        1440         2        3
# 3              3            80       757        1521         3        1
# 4              3            80       716        1200         2        1
# ...          ...           ...       ...         ...       ...      ...
# 13315          0            80      1252        3453         4        0
# 13316          3            80      1004        3600         5        1
# 13317          0            80       972        1141         2        1
# 13318          3            32       907        4689         4        1
# 13319          3            80       396         550         1        1
#
#           price  Bedroom
# 0       3907000        2
# 1      12000000        4
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.tree import DecisionTreeRegressor
lr=DecisionTreeRegressor()
lr.fit(x_train,y_train)
ypredict=lr.predict([[3,40,419,1056,2,1,2]])
ypredict=lr.predict(x_test)

# yactual=np.array([3907000])
# yactual
ypredict
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([ 4388333.25, 15000000.  , 28000000.  , ...,  5500000.  ,
#        42500000.  , 25000000.  ])

# %%
lr.score(x_train,y_train)
# Out:
# 0.999511434114516

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
print(mean_absolute_error(y_test,ypredict))
# Out:
# 4435425.1472819075

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,ypredict))
# Out:
# 0.22347256307087038

# %%
import pickle
file=open('bengaluruhouse.pkl','wb')
pickle.dump(lr,file)
